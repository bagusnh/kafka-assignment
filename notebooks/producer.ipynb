# %%
# !pip install confluent-kafka
# Out:
# Requirement already satisfied: confluent-kafka in /opt/conda/lib/python3.11/site-packages (2.13.0)

# %%
import json
import time
import random
from confluent_kafka import Producer

producer_config = {
    "bootstrap.servers": "kafka:9092"
}

producer = Producer(producer_config)
users = ["user_1", "user_2", "user_3"]

def delivery_report(err, msg):
    if err:
        print("Delivery failed:", err)
    else:
        print(f"Delivered {msg.value().decode('utf-8')}")
        print(f"Delivered to {msg.topic()} : partition {msg.partition()} : at offset {msg.offset()}")

while True:
    user = random.choice(users)
    user_event = {
        "user": user,
        "event_type": "click",
        "timestamp": time.time()
    }

    value = json.dumps(user_event).encode("utf-8")

    producer.produce(
        topic="events_topic",
        key=user,
        value=value,
        callback=delivery_report
    )

    producer.poll(0)
    time.sleep(5)

producer.flush()
# Out:
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771995693.0401695}
# Delivered to events_topic : partition 2 : at offset 0
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771995698.041212}
# Delivered to events_topic : partition 2 : at offset 1
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771995703.0487769}
# Delivered to events_topic : partition 1 : at offset 0
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771995708.0549629}
# Delivered to events_topic : partition 2 : at offset 2
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771995713.0605173}
# Delivered to events_topic : partition 2 : at offset 3
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771995718.0654562}
# Delivered to events_topic : partition 2 : at offset 4
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771995723.0683594}
# Delivered to events_topic : partition 1 : at offset 1
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771995728.0714383}
# Delivered to events_topic : partition 2 : at offset 5
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771995733.0757587}
# Delivered to events_topic : partition 2 : at offset 6
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771995738.079458}
# Delivered to events_topic : partition 2 : at offset 7
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771995743.081765}
# Delivered to events_topic : partition 2 : at offset 8
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771995748.089482}
# Delivered to events_topic : partition 2 : at offset 9
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771995753.0999608}
# Delivered to events_topic : partition 1 : at offset 2
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771995758.1692898}
# Delivered to events_topic : partition 1 : at offset 3
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771995763.1743584}
# Delivered to events_topic : partition 2 : at offset 10
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771995768.17689}
# Delivered to events_topic : partition 2 : at offset 11
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771995773.1797373}
# Delivered to events_topic : partition 2 : at offset 12
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771995778.1839116}
# Delivered to events_topic : partition 1 : at offset 4
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771995783.193179}
# Delivered to events_topic : partition 2 : at offset 13
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771995788.2009337}
# Delivered to events_topic : partition 2 : at offset 14
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771995793.2084975}
# Delivered to events_topic : partition 2 : at offset 15
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771995798.2107027}
# Delivered to events_topic : partition 1 : at offset 5
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771995803.2134469}
# Delivered to events_topic : partition 2 : at offset 16
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771995808.2146096}
# Delivered to events_topic : partition 2 : at offset 17
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771995813.2176638}
# Delivered to events_topic : partition 1 : at offset 6
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771995818.2309136}
# Delivered to events_topic : partition 1 : at offset 7
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771995823.2430112}
# Delivered to events_topic : partition 2 : at offset 18
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771995828.2450032}
# Delivered to events_topic : partition 2 : at offset 19
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771995833.248037}
# Delivered to events_topic : partition 2 : at offset 20
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771995838.2525785}
# Delivered to events_topic : partition 2 : at offset 21
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771995843.2575483}
# Delivered to events_topic : partition 2 : at offset 22
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771995848.2563088}
# Delivered to events_topic : partition 1 : at offset 8
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771995853.2662454}
# Delivered to events_topic : partition 1 : at offset 9
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771995858.2776248}
# Delivered to events_topic : partition 2 : at offset 23
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771995863.2825243}
# Delivered to events_topic : partition 1 : at offset 10
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771995868.2865155}
# Delivered to events_topic : partition 1 : at offset 11
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771995873.2914662}
# Delivered to events_topic : partition 1 : at offset 12
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771995878.2995424}
# Delivered to events_topic : partition 1 : at offset 13
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771995883.3039687}
# Delivered to events_topic : partition 2 : at offset 24
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771995888.316413}
# Delivered to events_topic : partition 2 : at offset 25
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771995893.3230052}
# Delivered to events_topic : partition 1 : at offset 14
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771995898.326599}
# Delivered to events_topic : partition 2 : at offset 26
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771995903.3304644}
# Delivered to events_topic : partition 1 : at offset 15
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771995908.336922}
# Delivered to events_topic : partition 1 : at offset 16
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771995913.3496053}
# Delivered to events_topic : partition 2 : at offset 27
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771995918.3585145}
# Delivered to events_topic : partition 2 : at offset 28
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771995923.3610358}
# Delivered to events_topic : partition 2 : at offset 29
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771995928.3668919}
# Delivered to events_topic : partition 1 : at offset 17
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771995933.3727818}
# Delivered to events_topic : partition 2 : at offset 30
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771995938.3756127}
# Delivered to events_topic : partition 2 : at offset 31
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771995943.385343}
# Delivered to events_topic : partition 1 : at offset 18
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771995948.390747}
# Delivered to events_topic : partition 2 : at offset 32
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771995953.3983843}
# Delivered to events_topic : partition 2 : at offset 33
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771995958.4031188}
# Delivered to events_topic : partition 2 : at offset 34
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771995963.404064}
# Delivered to events_topic : partition 1 : at offset 19
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771995968.406386}
# Delivered to events_topic : partition 2 : at offset 35
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771995973.4128263}
# Delivered to events_topic : partition 1 : at offset 20
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771995978.4164588}
# Delivered to events_topic : partition 2 : at offset 36
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771995983.425981}
# Delivered to events_topic : partition 2 : at offset 37
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771995988.4273863}
# Delivered to events_topic : partition 1 : at offset 21
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771995993.429613}
# Delivered to events_topic : partition 2 : at offset 38
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771995998.436898}
# Delivered to events_topic : partition 1 : at offset 22
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996003.448801}
# Delivered to events_topic : partition 2 : at offset 39
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996008.4539094}
# Delivered to events_topic : partition 2 : at offset 40
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771996013.4674087}
# Delivered to events_topic : partition 2 : at offset 41
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771996018.483677}
# Delivered to events_topic : partition 2 : at offset 42
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771996023.4880748}
# Delivered to events_topic : partition 1 : at offset 23
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771996028.489782}
# Delivered to events_topic : partition 2 : at offset 43
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771996033.4960938}
# Delivered to events_topic : partition 1 : at offset 24
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996038.5005047}
# Delivered to events_topic : partition 2 : at offset 44
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771996043.5106354}
# Delivered to events_topic : partition 1 : at offset 25
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996048.5216973}
# Delivered to events_topic : partition 2 : at offset 45
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771996053.5328646}
# Delivered to events_topic : partition 2 : at offset 46
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996058.5500894}
# Delivered to events_topic : partition 2 : at offset 47
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771996063.5652092}
# Delivered to events_topic : partition 2 : at offset 48
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996068.5718207}
# Delivered to events_topic : partition 2 : at offset 49
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996073.5854793}
# Delivered to events_topic : partition 2 : at offset 50
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771996078.5923567}
# Delivered to events_topic : partition 1 : at offset 26
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996083.5951693}
# Delivered to events_topic : partition 2 : at offset 51
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996088.5991204}
# Delivered to events_topic : partition 2 : at offset 52
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771996093.603745}
# Delivered to events_topic : partition 1 : at offset 27
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771996098.6106539}
# Delivered to events_topic : partition 2 : at offset 53
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771996103.6157515}
# Delivered to events_topic : partition 2 : at offset 54
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996108.6188247}
# Delivered to events_topic : partition 2 : at offset 55
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771996113.622951}
# Delivered to events_topic : partition 1 : at offset 28
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996118.6312683}
# Delivered to events_topic : partition 2 : at offset 56
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771996123.6450117}
# Delivered to events_topic : partition 2 : at offset 57
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771996128.6492088}
# Delivered to events_topic : partition 2 : at offset 58
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996133.6539507}
# Delivered to events_topic : partition 2 : at offset 59
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771996138.6568258}
# Delivered to events_topic : partition 2 : at offset 60
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771996143.6592083}
# Delivered to events_topic : partition 2 : at offset 61
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771996148.663428}
# Delivered to events_topic : partition 1 : at offset 29
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771996153.6801543}
# Delivered to events_topic : partition 2 : at offset 62
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771996158.6851776}
# Delivered to events_topic : partition 1 : at offset 30
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771996163.6876724}
# Delivered to events_topic : partition 2 : at offset 63
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996168.6939106}
# Delivered to events_topic : partition 2 : at offset 64
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996173.6999009}
# Delivered to events_topic : partition 2 : at offset 65
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996178.7047358}
# Delivered to events_topic : partition 2 : at offset 66
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771996183.7101545}
# Delivered to events_topic : partition 1 : at offset 31
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771996188.7173033}
# Delivered to events_topic : partition 1 : at offset 32
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996193.7232401}
# Delivered to events_topic : partition 2 : at offset 67
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996198.7301767}
# Delivered to events_topic : partition 2 : at offset 68
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771996203.732424}
# Delivered to events_topic : partition 1 : at offset 33
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771996208.7333326}
# Delivered to events_topic : partition 1 : at offset 34
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771996213.7407339}
# Delivered to events_topic : partition 2 : at offset 69
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996218.744877}
# Delivered to events_topic : partition 2 : at offset 70
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771996223.749174}
# Delivered to events_topic : partition 2 : at offset 71
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771996228.7555647}
# Delivered to events_topic : partition 2 : at offset 72
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771996233.7636971}
# Delivered to events_topic : partition 2 : at offset 73
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996238.7686987}
# Delivered to events_topic : partition 2 : at offset 74
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996243.7783532}
# Delivered to events_topic : partition 2 : at offset 75
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771996248.782691}
# Delivered to events_topic : partition 1 : at offset 35
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996253.7882028}
# Delivered to events_topic : partition 2 : at offset 76
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771996258.7932973}
# Delivered to events_topic : partition 2 : at offset 77
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771996263.7948108}
# Delivered to events_topic : partition 2 : at offset 78
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771996268.8018677}
# Delivered to events_topic : partition 2 : at offset 79
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771996278.806776}
# Delivered to events_topic : partition 1 : at offset 36
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771996283.8140912}
# Delivered to events_topic : partition 1 : at offset 37
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771996288.819272}
# Delivered to events_topic : partition 1 : at offset 38
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996293.8271472}
# Delivered to events_topic : partition 2 : at offset 81
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996298.83773}
# Delivered to events_topic : partition 2 : at offset 82
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771996303.8417192}
# Delivered to events_topic : partition 1 : at offset 39
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996308.84621}
# Delivered to events_topic : partition 2 : at offset 83
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771996313.8511832}
# Delivered to events_topic : partition 2 : at offset 84
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996318.8551917}
# Delivered to events_topic : partition 2 : at offset 85
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771996323.8619764}
# Delivered to events_topic : partition 1 : at offset 40
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771996331.5738902}
# Delivered to events_topic : partition 2 : at offset 86
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996336.5788486}
# Delivered to events_topic : partition 2 : at offset 87
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771996341.5854168}
# Delivered to events_topic : partition 2 : at offset 88
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771996346.5885868}
# Delivered to events_topic : partition 2 : at offset 89
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996351.5905068}
# Delivered to events_topic : partition 2 : at offset 90
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771996356.5976143}
# Delivered to events_topic : partition 1 : at offset 41
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996361.6299033}
# Delivered to events_topic : partition 2 : at offset 91
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771996366.6458416}
# Delivered to events_topic : partition 2 : at offset 92
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771996371.6572692}
# Delivered to events_topic : partition 1 : at offset 42
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771996376.663954}
# Delivered to events_topic : partition 1 : at offset 43
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771996381.671828}
# Delivered to events_topic : partition 1 : at offset 44
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996386.676511}
# Delivered to events_topic : partition 2 : at offset 93
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771996949.7444923}
# Delivered to events_topic : partition 1 : at offset 45
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771996954.7506094}
# Delivered to events_topic : partition 1 : at offset 46
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996959.7553105}
# Delivered to events_topic : partition 2 : at offset 94
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996964.7621195}
# Delivered to events_topic : partition 2 : at offset 95
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996969.769415}
# Delivered to events_topic : partition 2 : at offset 96
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771996974.7733457}
# Delivered to events_topic : partition 2 : at offset 97
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771996979.7797296}
# Delivered to events_topic : partition 1 : at offset 47
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771996984.7865186}
# Delivered to events_topic : partition 1 : at offset 48
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771996989.799556}
# Delivered to events_topic : partition 1 : at offset 49
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771996994.8033826}
# Delivered to events_topic : partition 2 : at offset 98
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771996999.8108144}
# Delivered to events_topic : partition 1 : at offset 50
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771997004.817724}
# Delivered to events_topic : partition 2 : at offset 99
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771997009.819232}
# Delivered to events_topic : partition 1 : at offset 51
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771997014.8245392}
# Delivered to events_topic : partition 2 : at offset 100
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771997019.830658}
# Delivered to events_topic : partition 1 : at offset 52
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771997024.8366752}
# Delivered to events_topic : partition 1 : at offset 53
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771997029.8419416}
# Delivered to events_topic : partition 1 : at offset 54
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771997034.8440995}
# Delivered to events_topic : partition 2 : at offset 101
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771997039.8514998}
# Delivered to events_topic : partition 2 : at offset 102
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771997044.859826}
# Delivered to events_topic : partition 2 : at offset 103
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771997049.8644695}
# Delivered to events_topic : partition 1 : at offset 55
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771997054.8664048}
# Delivered to events_topic : partition 2 : at offset 104
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771997059.869697}
# Delivered to events_topic : partition 1 : at offset 56
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771997064.873944}
# Delivered to events_topic : partition 2 : at offset 105
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771997069.8765771}
# Delivered to events_topic : partition 1 : at offset 57
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771997074.8783581}
# Delivered to events_topic : partition 2 : at offset 106
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771997079.894429}
# Delivered to events_topic : partition 1 : at offset 58
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771997084.8969731}
# Delivered to events_topic : partition 2 : at offset 107
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771997089.902255}
# Delivered to events_topic : partition 2 : at offset 108
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 38
#      30     producer.produce(
#      31         topic="events_topic",
#      32         key=user,
#      33         value=value,
#      34         callback=delivery_report
#      35     )
#      37     producer.poll(0)
# ---> 38     time.sleep(5)
#      40 producer.flush()
#
# KeyboardInterrupt:
