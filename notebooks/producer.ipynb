# %%
# !pip install confluent-kafka
# Out:
# Requirement already satisfied: confluent-kafka in /Users/bagusnugroho/Documents/file/DE/kafka/kafka-assignment/env/lib/python3.13/site-packages (2.13.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import json
import time
import random
from confluent_kafka import Producer

producer_config = {
    "bootstrap.servers": "kafka:9092"
}

producer = Producer(producer_config)
users = ["user_1", "user_2", "user_3"]

def delivery_report(err, msg):
    if err:
        print("Delivery failed:", err)
    else:
        print(f"Delivered {msg.value().decode('utf-8')}")
        print(f"Delivered to {msg.topic()} : partition {msg.partition()} : at offset {msg.offset()}")

while True:
    user = random.choice(users)
    user_event = {
        "user": user,
        "event_type": "click",
        "timestamp": time.time()
    }

    value = json.dumps(user_event).encode("utf-8")

    producer.produce(
        topic="events_topic",
        key=user,
        value=value,
        callback=delivery_report
    )

    producer.poll(0)
    time.sleep(5)

producer.flush()
# Out:
# %4|1771995476.676|TERMINATE|rdkafka#producer-1| [thrd:app]: Producer terminating with 6 messages (439 bytes) still in queue or transit: use flush() to wait for outstanding message delivery
# %3|1771995476.679|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT)
# %3|1771995477.741|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1771995507.863|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 23 identical error(s) suppressed)
# %3|1771995537.939|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 23 identical error(s) suppressed)
# %3|1771995569.062|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 24 identical error(s) suppressed)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 38
#      30 producer.produce(
#      31     topic="events_topic",
#      32     key=user,
#      33     value=value,
#      34     callback=delivery_report
#      35 )
#      37 producer.poll(0)
# ---> 38 time.sleep(5)
#
# KeyboardInterrupt:
# %3|1771995599.230|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 23 identical error(s) suppressed)
# %3|1771995630.285|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 23 identical error(s) suppressed)
# %3|1771995660.393|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 5ms in state CONNECT, 23 identical error(s) suppressed)
# %3|1771995690.563|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 5ms in state CONNECT, 23 identical error(s) suppressed)
# %3|1771995721.634|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 23 identical error(s) suppressed)
# %3|1771995752.738|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 6ms in state CONNECT, 24 identical error(s) suppressed)
# %3|1771995783.314|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 24 identical error(s) suppressed)
# %3|1771995814.443|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 24 identical error(s) suppressed)
# %3|1771995845.055|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 5ms in state CONNECT, 23 identical error(s) suppressed)
# %3|1771995875.667|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 23 identical error(s) suppressed)
# %3|1771995906.341|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 23 identical error(s) suppressed)
# %3|1771995936.449|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 23 identical error(s) suppressed)
# %3|1771995966.514|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 23 identical error(s) suppressed)
# %3|1771995996.685|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 23 identical error(s) suppressed)
# %3|1771996027.254|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 23 identical error(s) suppressed)
# %3|1771996057.878|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 23 identical error(s) suppressed)
# %3|1771996088.476|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 23 identical error(s) suppressed)
# %3|1771996119.587|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 24 identical error(s) suppressed)
# %3|1771996150.219|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 23 identical error(s) suppressed)
# %3|1771996180.381|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 23 identical error(s) suppressed)
# %3|1771996210.498|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 5ms in state CONNECT, 23 identical error(s) suppressed)
# %3|1771996241.022|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 23 identical error(s) suppressed)
# %3|1771996271.131|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 23 identical error(s) suppressed)
# %3|1771996301.880|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 6ms in state CONNECT, 24 identical error(s) suppressed)
# %3|1771996331.899|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 20 identical error(s) suppressed)
# %3|1771996920.104|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 21 identical error(s) suppressed)
# %3|1771996950.373|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 22 identical error(s) suppressed)
# %3|1771996980.463|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 21 identical error(s) suppressed)
# %3|1771997011.518|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 21 identical error(s) suppressed)
# %3|1771997041.620|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 20 identical error(s) suppressed)
# %3|1771997071.798|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 21 identical error(s) suppressed)
# %3|1771997102.839|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 21 identical error(s) suppressed)
# %3|1771997133.016|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 22 identical error(s) suppressed)
# %3|1771997163.144|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 20 identical error(s) suppressed)
# %3|1771997193.200|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 20 identical error(s) suppressed)
# %3|1771997224.329|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 22 identical error(s) suppressed)
# %3|1771997254.508|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 21 identical error(s) suppressed)
# %3|1771997285.561|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 1ms in state CONNECT, 21 identical error(s) suppressed)
# %3|1771997315.757|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 21 identical error(s) suppressed)
# %3|1771997345.829|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 5ms in state CONNECT, 20 identical error(s) suppressed)
# %3|1771997375.998|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 21 identical error(s) suppressed)
# %3|1771997407.059|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 21 identical error(s) suppressed)
# %3|1771997437.174|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 21 identical error(s) suppressed)
# %3|1771997467.342|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 21 identical error(s) suppressed)
# %3|1771997498.403|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 21 identical error(s) suppressed)
# %3|1771997528.515|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 21 identical error(s) suppressed)
# %3|1771997559.626|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 21 identical error(s) suppressed)
# %3|1771997589.787|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 22 identical error(s) suppressed)
# %3|1771997619.888|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 4ms in state CONNECT, 21 identical error(s) suppressed)
# %3|1771997649.983|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 20 identical error(s) suppressed)
# %3|1771997680.096|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 3ms in state CONNECT, 21 identical error(s) suppressed)
# %3|1771997710.205|FAIL|rdkafka#producer-2| [thrd:kafka:9092/bootstrap]: kafka:9092/bootstrap: Failed to resolve 'kafka:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT, 20 identical error(s) suppressed)
