# %%
# !pip install confluent-kafka
# Out:
# Requirement already satisfied: confluent-kafka in /opt/conda/lib/python3.11/site-packages (2.13.0)

# %%
import json
import time
import random
from confluent_kafka import Producer

producer_config = {
    "bootstrap.servers": "kafka:9092"
}

producer = Producer(producer_config)
users = ["user_1", "user_2", "user_3"]

def delivery_report(err, msg):
    if err:
        print("Delivery failed:", err)
    else:
        print(f"Delivered {msg.value().decode('utf-8')}")
        print(f"Delivered to {msg.topic()} : partition {msg.partition()} : at offset {msg.offset()}")

while True:
    user = random.choice(users)
    user_event = {
        "user": user,
        "event_type": "click",
        "timestamp": time.time()
    }

    value = json.dumps(user_event).encode("utf-8")

    producer.produce(
        topic="events_topic",
        key=user,
        value=value,
        callback=delivery_report
    )

    producer.poll(0)
    time.sleep(5)

producer.flush()
# Out:
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771997965.322074}
# Delivered to events_topic : partition 2 : at offset 109
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771997970.3267462}
# Delivered to events_topic : partition 2 : at offset 110
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771997975.3319888}
# Delivered to events_topic : partition 2 : at offset 111
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771997980.3336558}
# Delivered to events_topic : partition 2 : at offset 112
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771997985.3387356}
# Delivered to events_topic : partition 2 : at offset 113
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771997990.341342}
# Delivered to events_topic : partition 2 : at offset 114
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771997995.3437417}
# Delivered to events_topic : partition 2 : at offset 115
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771998000.3462062}
# Delivered to events_topic : partition 2 : at offset 116
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771998005.3497672}
# Delivered to events_topic : partition 2 : at offset 117
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771998010.3563735}
# Delivered to events_topic : partition 1 : at offset 60
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771998015.3640044}
# Delivered to events_topic : partition 1 : at offset 61
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771998020.3688755}
# Delivered to events_topic : partition 2 : at offset 118
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771998025.3727276}
# Delivered to events_topic : partition 2 : at offset 119
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771998030.37697}
# Delivered to events_topic : partition 2 : at offset 120
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771998035.3833442}
# Delivered to events_topic : partition 2 : at offset 121
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771998040.3882544}
# Delivered to events_topic : partition 2 : at offset 122
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771998045.3931997}
# Delivered to events_topic : partition 2 : at offset 123
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771998050.395044}
# Delivered to events_topic : partition 2 : at offset 124
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771998055.3988981}
# Delivered to events_topic : partition 2 : at offset 125
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771998060.4109375}
# Delivered to events_topic : partition 1 : at offset 62
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771998065.4148886}
# Delivered to events_topic : partition 2 : at offset 126
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771998070.4180148}
# Delivered to events_topic : partition 2 : at offset 127
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771998075.4225664}
# Delivered to events_topic : partition 2 : at offset 128
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771998080.4290864}
# Delivered to events_topic : partition 2 : at offset 129
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771998085.432971}
# Delivered to events_topic : partition 2 : at offset 130
# Delivered {"user": "user_3", "event_type": "click", "timestamp": 1771998090.4412618}
# Delivered to events_topic : partition 1 : at offset 63
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771998095.4516728}
# Delivered to events_topic : partition 2 : at offset 131
# Delivered {"user": "user_1", "event_type": "click", "timestamp": 1771998100.4583042}
# Delivered to events_topic : partition 2 : at offset 132
# Delivered {"user": "user_2", "event_type": "click", "timestamp": 1771998105.4793124}
# Delivered to events_topic : partition 2 : at offset 133
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 38
#      30     producer.produce(
#      31         topic="events_topic",
#      32         key=user,
#      33         value=value,
#      34         callback=delivery_report
#      35     )
#      37     producer.poll(0)
# ---> 38     time.sleep(5)
#      40 producer.flush()
#
# KeyboardInterrupt:
