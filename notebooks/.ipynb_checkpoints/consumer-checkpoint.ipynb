# %%
# !pip install confluent-kafka
# Out:
# Requirement already satisfied: confluent-kafka in /opt/conda/lib/python3.11/site-packages (2.13.0)

# %%
from confluent_kafka import Consumer
import json
from collections import defaultdict

conf = {
    "bootstrap.servers": "kafka:9092",
    "group.id": "event-consumer-group",
    "auto.offset.reset": "earliest"
}

consumer = Consumer(conf)
consumer.subscribe(["events_topic"])

count_per_user = defaultdict(int)

while True:
    msg = consumer.poll(1.0)

    if msg is None:
        continue
    if msg.error():
        print(msg.error())
        continue

    data = json.loads(msg.value().decode())
    user = msg.key().decode()

    count_per_user[user] += 1

    print(
        f"partition={msg.partition()}, "
        f"user={user}, "
        f"total={count_per_user[user]}"
    )
# Out:
# partition=2, user=user_2, total=1
# partition=2, user=user_2, total=2
# partition=2, user=user_2, total=3
# partition=2, user=user_2, total=4
# partition=2, user=user_1, total=1
# partition=2, user=user_2, total=5
# partition=2, user=user_2, total=6
# partition=2, user=user_2, total=7
# partition=2, user=user_2, total=8
# partition=2, user=user_1, total=2
# partition=2, user=user_1, total=3
# partition=2, user=user_2, total=9
# partition=2, user=user_1, total=4
# partition=2, user=user_1, total=5
# partition=2, user=user_1, total=6
# partition=2, user=user_1, total=7
# partition=2, user=user_1, total=8
# partition=2, user=user_1, total=9
# partition=2, user=user_2, total=10
# partition=2, user=user_2, total=11
# partition=1, user=user_3, total=1
# partition=1, user=user_3, total=2
# partition=1, user=user_3, total=3
# partition=1, user=user_3, total=4
# partition=1, user=user_3, total=5
# partition=1, user=user_3, total=6
# partition=1, user=user_3, total=7
# partition=1, user=user_3, total=8
# partition=2, user=user_2, total=12
# partition=2, user=user_2, total=13
# partition=2, user=user_1, total=10
# partition=1, user=user_3, total=9
# partition=1, user=user_3, total=10
# partition=2, user=user_1, total=11
# partition=1, user=user_3, total=11
# partition=1, user=user_3, total=12
# partition=1, user=user_3, total=13
# partition=1, user=user_3, total=14
# partition=2, user=user_2, total=14
# partition=2, user=user_2, total=15
# partition=1, user=user_3, total=15
# partition=2, user=user_1, total=12
# partition=1, user=user_3, total=16
# partition=1, user=user_3, total=17
# partition=2, user=user_1, total=13
# partition=2, user=user_1, total=14
# partition=2, user=user_2, total=16
# partition=1, user=user_3, total=18
# partition=2, user=user_2, total=17
# partition=2, user=user_1, total=15
# partition=1, user=user_3, total=19
# partition=2, user=user_1, total=16
# partition=2, user=user_1, total=17
# partition=2, user=user_2, total=18
# partition=1, user=user_3, total=20
# partition=2, user=user_1, total=18
# partition=1, user=user_3, total=21
# partition=2, user=user_2, total=19
# partition=2, user=user_2, total=20
# partition=1, user=user_3, total=22
# partition=2, user=user_1, total=19
# partition=1, user=user_3, total=23
# partition=2, user=user_1, total=20
# partition=2, user=user_1, total=21
# partition=2, user=user_2, total=21
# partition=2, user=user_2, total=22
# partition=1, user=user_3, total=24
# partition=2, user=user_2, total=23
# partition=1, user=user_3, total=25
# partition=2, user=user_1, total=22
# partition=1, user=user_3, total=26
# partition=2, user=user_1, total=23
# partition=2, user=user_2, total=24
# partition=2, user=user_1, total=24
# partition=2, user=user_2, total=25
# partition=2, user=user_1, total=25
# partition=2, user=user_1, total=26
